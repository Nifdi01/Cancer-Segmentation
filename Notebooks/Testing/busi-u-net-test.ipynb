# %%
import random

import pandas as pd
from matplotlib import pyplot as plt

from Model.Inference.Analyze import analyze_iou_across_images
from Model.Inference.Display import display_best_grid_prediction
from Model.zoo import UNetModel1024
from Visualizer.PathGrid import display_grid_from_path
# Out:
# 2025-07-17 23:17:23.872164: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-17 23:17:23.876469: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-17 23:17:23.889746: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752808643.910994  124615 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752808643.917203  124615 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752808643.933565  124615 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752808643.933582  124615 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752808643.933585  124615 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752808643.933586  124615 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-17 23:17:23.938738: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = UNetModel1024(weights="../../Model/zoo/weights/unet-1024-5050.weights.h5")
model = model.load_model()
output_dir = "../../CROPS"
image_idx = 10
mask_threshold = 0.7
grid_range = (4, 10)
index_range = [random.randint(0, 797) for _ in range(50)]

# %%
best_grid_size, iou_scores = display_best_grid_prediction(
    output_dir=output_dir,
    image_idx=image_idx,
    model=model,
    mask_threshold=mask_threshold,
    spacing=0,
    grid_range=grid_range
)

display_grid_from_path(output_dir, image_idx, best_grid_size, True, 0)
display_grid_from_path(output_dir, image_idx, best_grid_size, False, 0)
# Out:
# Grid size 4x4: IoU = 0.7001
# Grid size 5x5: IoU = 0.6988
# Grid size 6x6: IoU = 0.7860
# Grid size 7x7: IoU = 0.5703
# Grid size 8x8: IoU = 0.5070
# Grid size 9x9: IoU = 0.3444
# Grid size 10x10: IoU = 0.3253
#
# Best grid size: 6x6 with IoU = 0.7860
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step

# %%
results = analyze_iou_across_images(
    output_dir=output_dir,
    model=model,
    mask_threshold=mask_threshold,
    grid_range=grid_range,
    index_range=index_range
)
# Out:
# Processing image 1/50... Grid size 4x4: IoU = 0.4805
# Grid size 5x5: IoU = 0.5204
# Grid size 6x6: IoU = 0.3933
# Grid size 7x7: IoU = 0.4332
# Grid size 8x8: IoU = 0.3177
# Grid size 9x9: IoU = 0.2051
# Grid size 10x10: IoU = 0.1862
#
# Best grid size: 5x5 with IoU = 0.5204
# ✓ Best: 5x5 (IoU: 0.5204)
# Processing image 2/50... Grid size 4x4: IoU = 0.4544
# Grid size 5x5: IoU = 0.4236
# Grid size 6x6: IoU = 0.4285
# Grid size 7x7: IoU = 0.4546
# Grid size 8x8: IoU = 0.2716
# Grid size 9x9: IoU = 0.3489
# Grid size 10x10: IoU = 0.2422
#
# Best grid size: 7x7 with IoU = 0.4546
# ✓ Best: 7x7 (IoU: 0.4546)
# Processing image 3/50... Grid size 4x4: IoU = 0.5000
# Grid size 5x5: IoU = 0.6400
# Grid size 6x6: IoU = 0.3333
# Grid size 7x7: IoU = 0.4082
# Grid size 8x8: IoU = 0.4062
# Grid size 9x9: IoU = 0.3086
# Grid size 10x10: IoU = 0.2900
#
# Best grid size: 5x5 with IoU = 0.6400
# ✓ Best: 5x5 (IoU: 0.6400)
# Processing image 4/50... Grid size 4x4: IoU = 0.5899
# Grid size 5x5: IoU = 0.4738
# Grid size 6x6: IoU = 0.4431
# Grid size 7x7: IoU = 0.5561
# Grid size 8x8: IoU = 0.4109
# Grid size 9x9: IoU = 0.2968
# Grid size 10x10: IoU = 0.1475
#
# Best grid size: 4x4 with IoU = 0.5899
# ✓ Best: 4x4 (IoU: 0.5899)
# Processing image 5/50... Grid size 4x4: IoU = 0.8125
# Grid size 5x5: IoU = 0.7200
# Grid size 6x6: IoU = 0.6944
# Grid size 7x7: IoU = 0.5918
# Grid size 8x8: IoU = 0.5000
# Grid size 9x9: IoU = 0.4691
# Grid size 10x10: IoU = 0.2700
#
# Best grid size: 4x4 with IoU = 0.8125
# ✓ Best: 4x4 (IoU: 0.8125)
# Processing image 6/50... Grid size 4x4: IoU = 0.7715
# Grid size 5x5: IoU = 0.7835
# Grid size 6x6: IoU = 0.5885
# Grid size 7x7: IoU = 0.6133
# Grid size 8x8: IoU = 0.5017
# Grid size 9x9: IoU = 0.3940
# Grid size 10x10: IoU = 0.2779
#
# Best grid size: 5x5 with IoU = 0.7835
# ✓ Best: 5x5 (IoU: 0.7835)
# Processing image 7/50... Grid size 4x4: IoU = 0.1974
# Grid size 5x5: IoU = 0.3870
# Grid size 6x6: IoU = 0.3490
# Grid size 7x7: IoU = 0.2950
# Grid size 8x8: IoU = 0.2693
# Grid size 9x9: IoU = 0.1646
# Grid size 10x10: IoU = 0.1902
#
# Best grid size: 5x5 with IoU = 0.3870
# ✓ Best: 5x5 (IoU: 0.3870)
# Processing image 8/50... Grid size 4x4: IoU = 0.3328
# Grid size 5x5: IoU = 0.4131
# Grid size 6x6: IoU = 0.3933
# Grid size 7x7: IoU = 0.2968
# Grid size 8x8: IoU = 0.2274
# Grid size 9x9: IoU = 0.3220
# Grid size 10x10: IoU = 0.2118
#
# Best grid size: 5x5 with IoU = 0.4131
# ✓ Best: 5x5 (IoU: 0.4131)
# Processing image 9/50... Grid size 4x4: IoU = 0.6250
# Grid size 5x5: IoU = 0.6800
# Grid size 6x6: IoU = 0.4722
# Grid size 7x7: IoU = 0.5510
# Grid size 8x8: IoU = 0.4375
# Grid size 9x9: IoU = 0.3210
# Grid size 10x10: IoU = 0.2800
#
# Best grid size: 5x5 with IoU = 0.6800
# ✓ Best: 5x5 (IoU: 0.6800)
# Processing image 10/50... Grid size 4x4: IoU = 0.5625
# Grid size 5x5: IoU = 0.6400
# Grid size 6x6: IoU = 0.4266
# Grid size 7x7: IoU = 0.3998
# Grid size 8x8: IoU = 0.2372
# Grid size 9x9: IoU = 0.2711
# Grid size 10x10: IoU = 0.2320
#
# Best grid size: 5x5 with IoU = 0.6400
# ✓ Best: 5x5 (IoU: 0.6400)
# Processing image 11/50... Grid size 4x4: IoU = 0.6875
# Grid size 5x5: IoU = 0.6400
# Grid size 6x6: IoU = 0.3889
# Grid size 7x7: IoU = 0.4490
# Grid size 8x8: IoU = 0.3594
# Grid size 9x9: IoU = 0.2963
# Grid size 10x10: IoU = 0.1500
#
# Best grid size: 4x4 with IoU = 0.6875
# ✓ Best: 4x4 (IoU: 0.6875)
# Processing image 12/50... Grid size 4x4: IoU = 0.3750
# Grid size 5x5: IoU = 0.4000
# Grid size 6x6: IoU = 0.3333
# Grid size 7x7: IoU = 0.2449
# Grid size 8x8: IoU = 0.1406
# Grid size 9x9: IoU = 0.0741
# Grid size 10x10: IoU = 0.0900
#
# Best grid size: 5x5 with IoU = 0.4000
# ✓ Best: 5x5 (IoU: 0.4000)
# Processing image 13/50... Grid size 4x4: IoU = 0.4708
# Grid size 5x5: IoU = 0.4057
# Grid size 6x6: IoU = 0.4607
# Grid size 7x7: IoU = 0.4190
# Grid size 8x8: IoU = 0.2750
# Grid size 9x9: IoU = 0.2016
# Grid size 10x10: IoU = 0.1349
#
# Best grid size: 4x4 with IoU = 0.4708
# ✓ Best: 4x4 (IoU: 0.4708)
# Processing image 14/50... Grid size 4x4: IoU = 0.6875
# Grid size 5x5: IoU = 0.6400
# Grid size 6x6: IoU = 0.4444
# Grid size 7x7: IoU = 0.5102
# Grid size 8x8: IoU = 0.4531
# Grid size 9x9: IoU = 0.3951
# Grid size 10x10: IoU = 0.3900
#
# Best grid size: 4x4 with IoU = 0.6875
# ✓ Best: 4x4 (IoU: 0.6875)
# Processing image 15/50... Grid size 4x4: IoU = 0.5710
# Grid size 5x5: IoU = 0.5300
# Grid size 6x6: IoU = 0.4919
# Grid size 7x7: IoU = 0.3930
# Grid size 8x8: IoU = 0.3215
# Grid size 9x9: IoU = 0.2811
# Grid size 10x10: IoU = 0.1668
#
# Best grid size: 4x4 with IoU = 0.5710
# ✓ Best: 4x4 (IoU: 0.5710)
# Processing image 16/50... Grid size 4x4: IoU = 0.4016
# Grid size 5x5: IoU = 0.4510
# Grid size 6x6: IoU = 0.4013
# Grid size 7x7: IoU = 0.3923
# Grid size 8x8: IoU = 0.3544
# Grid size 9x9: IoU = 0.3154
# Grid size 10x10: IoU = 0.2416
#
# Best grid size: 5x5 with IoU = 0.4510
# ✓ Best: 5x5 (IoU: 0.4510)
# Processing image 17/50... Grid size 4x4: IoU = 0.6526
# Grid size 5x5: IoU = 0.4424
# Grid size 6x6: IoU = 0.5576
# Grid size 7x7: IoU = 0.5047
# Grid size 8x8: IoU = 0.4190
# Grid size 9x9: IoU = 0.4379
# Grid size 10x10: IoU = 0.3705
#
# Best grid size: 4x4 with IoU = 0.6526
# ✓ Best: 4x4 (IoU: 0.6526)
# Processing image 18/50... Grid size 4x4: IoU = 0.3545
# Grid size 5x5: IoU = 0.2314
# Grid size 6x6: IoU = 0.3246
# Grid size 7x7: IoU = 0.3648
# Grid size 8x8: IoU = 0.2877
# Grid size 9x9: IoU = 0.3046
# Grid size 10x10: IoU = 0.1940
#
# Best grid size: 7x7 with IoU = 0.3648
# ✓ Best: 7x7 (IoU: 0.3648)
# Processing image 19/50... Grid size 4x4: IoU = 0.4731
# Grid size 5x5: IoU = 0.3859
# Grid size 6x6: IoU = 0.2730
# Grid size 7x7: IoU = 0.2530
# Grid size 8x8: IoU = 0.1413
# Grid size 9x9: IoU = 0.0690
# Grid size 10x10: IoU = 0.0663
#
# Best grid size: 4x4 with IoU = 0.4731
# ✓ Best: 4x4 (IoU: 0.4731)
# Processing image 20/50... Grid size 4x4: IoU = 0.5156
# Grid size 5x5: IoU = 0.4277
# Grid size 6x6: IoU = 0.5234
# Grid size 7x7: IoU = 0.4202
# Grid size 8x8: IoU = 0.4334
# Grid size 9x9: IoU = 0.2325
# Grid size 10x10: IoU = 0.1722
#
# Best grid size: 6x6 with IoU = 0.5234
# ✓ Best: 6x6 (IoU: 0.5234)
# Processing image 21/50... Grid size 4x4: IoU = 0.7317
# Grid size 5x5: IoU = 0.6192
# Grid size 6x6: IoU = 0.6516
# Grid size 7x7: IoU = 0.4948
# Grid size 8x8: IoU = 0.4458
# Grid size 9x9: IoU = 0.3611
# Grid size 10x10: IoU = 0.1886
#
# Best grid size: 4x4 with IoU = 0.7317
# ✓ Best: 4x4 (IoU: 0.7317)
# Processing image 22/50... Grid size 4x4: IoU = 0.7375
# Grid size 5x5: IoU = 0.4833
# Grid size 6x6: IoU = 0.4912
# Grid size 7x7: IoU = 0.3011
# Grid size 8x8: IoU = 0.2076
# Grid size 9x9: IoU = 0.1762
# Grid size 10x10: IoU = 0.0960
#
# Best grid size: 4x4 with IoU = 0.7375
# ✓ Best: 4x4 (IoU: 0.7375)
# Processing image 23/50... Grid size 4x4: IoU = 0.8125
# Grid size 5x5: IoU = 0.8000
# Grid size 6x6: IoU = 0.5278
# Grid size 7x7: IoU = 0.4286
# Grid size 8x8: IoU = 0.4219
# Grid size 9x9: IoU = 0.2716
# Grid size 10x10: IoU = 0.2000
#
# Best grid size: 4x4 with IoU = 0.8125
# ✓ Best: 4x4 (IoU: 0.8125)
# Processing image 24/50... Grid size 4x4: IoU = 0.6250
# Grid size 5x5: IoU = 0.5600
# Grid size 6x6: IoU = 0.4444
# Grid size 7x7: IoU = 0.3673
# Grid size 8x8: IoU = 0.4688
# Grid size 9x9: IoU = 0.3704
# Grid size 10x10: IoU = 0.2700
#
# Best grid size: 4x4 with IoU = 0.6250
# ✓ Best: 4x4 (IoU: 0.6250)
# Processing image 25/50... Grid size 4x4: IoU = 0.6024
# Grid size 5x5: IoU = 0.6628
# Grid size 6x6: IoU = 0.6761
# Grid size 7x7: IoU = 0.5546
# Grid size 8x8: IoU = 0.3416
# Grid size 9x9: IoU = 0.1935
# Grid size 10x10: IoU = 0.1690
#
# Best grid size: 6x6 with IoU = 0.6761
# ✓ Best: 6x6 (IoU: 0.6761)
# Processing image 26/50... Grid size 4x4: IoU = 0.4553
# Grid size 5x5: IoU = 0.3642
# Grid size 6x6: IoU = 0.4631
# Grid size 7x7: IoU = 0.4342
# Grid size 8x8: IoU = 0.3583
# Grid size 9x9: IoU = 0.2275
# Grid size 10x10: IoU = 0.1965
#
# Best grid size: 6x6 with IoU = 0.4631
# ✓ Best: 6x6 (IoU: 0.4631)
# Processing image 27/50... Grid size 4x4: IoU = 0.5625
# Grid size 5x5: IoU = 0.4400
# Grid size 6x6: IoU = 0.6111
# Grid size 7x7: IoU = 0.4082
# Grid size 8x8: IoU = 0.2812
# Grid size 9x9: IoU = 0.2469
# Grid size 10x10: IoU = 0.1700
#
# Best grid size: 6x6 with IoU = 0.6111
# ✓ Best: 6x6 (IoU: 0.6111)
# Processing image 28/50... Grid size 4x4: IoU = 0.6952
# Grid size 5x5: IoU = 0.5641
# Grid size 6x6: IoU = 0.6162
# Grid size 7x7: IoU = 0.3813
# Grid size 8x8: IoU = 0.4169
# Grid size 9x9: IoU = 0.3603
# Grid size 10x10: IoU = 0.3339
#
# Best grid size: 4x4 with IoU = 0.6952
# ✓ Best: 4x4 (IoU: 0.6952)
# Processing image 29/50... Grid size 4x4: IoU = 0.4411
# Grid size 5x5: IoU = 0.4682
# Grid size 6x6: IoU = 0.3835
# Grid size 7x7: IoU = 0.2915
# Grid size 8x8: IoU = 0.2737
# Grid size 9x9: IoU = 0.2284
# Grid size 10x10: IoU = 0.2044
#
# Best grid size: 5x5 with IoU = 0.4682
# ✓ Best: 5x5 (IoU: 0.4682)
# Processing image 30/50... Grid size 4x4: IoU = 0.3769
# Grid size 5x5: IoU = 0.3720
# Grid size 6x6: IoU = 0.4146
# Grid size 7x7: IoU = 0.4170
# Grid size 8x8: IoU = 0.2907
# Grid size 9x9: IoU = 0.3419
# Grid size 10x10: IoU = 0.2973
#
# Best grid size: 7x7 with IoU = 0.4170
# ✓ Best: 7x7 (IoU: 0.4170)
# Processing image 31/50... Grid size 4x4: IoU = 0.3750
# Grid size 5x5: IoU = 0.5601
# Grid size 6x6: IoU = 0.4967
# Grid size 7x7: IoU = 0.4064
# Grid size 8x8: IoU = 0.4401
# Grid size 9x9: IoU = 0.2803
# Grid size 10x10: IoU = 0.2803
#
# Best grid size: 5x5 with IoU = 0.5601
# ✓ Best: 5x5 (IoU: 0.5601)
# Processing image 32/50... Grid size 4x4: IoU = 0.0625
# Grid size 5x5: IoU = 0.2843
# Grid size 6x6: IoU = 0.2235
# Grid size 7x7: IoU = 0.2268
# Grid size 8x8: IoU = 0.2233
# Grid size 9x9: IoU = 0.1577
# Grid size 10x10: IoU = 0.1178
#
# Best grid size: 5x5 with IoU = 0.2843
# ✓ Best: 5x5 (IoU: 0.2843)
# Processing image 33/50... Grid size 4x4: IoU = 0.5177
# Grid size 5x5: IoU = 0.7059
# Grid size 6x6: IoU = 0.5972
# Grid size 7x7: IoU = 0.3921
# Grid size 8x8: IoU = 0.3155
# Grid size 9x9: IoU = 0.3497
# Grid size 10x10: IoU = 0.2127
#
# Best grid size: 5x5 with IoU = 0.7059
# ✓ Best: 5x5 (IoU: 0.7059)
# Processing image 34/50... Grid size 4x4: IoU = 0.5000
# Grid size 5x5: IoU = 0.3600
# Grid size 6x6: IoU = 0.2778
# Grid size 7x7: IoU = 0.2245
# Grid size 8x8: IoU = 0.1719
# Grid size 9x9: IoU = 0.1481
# Grid size 10x10: IoU = 0.0700
#
# Best grid size: 4x4 with IoU = 0.5000
# ✓ Best: 4x4 (IoU: 0.5000)
# Processing image 35/50... Grid size 4x4: IoU = 0.8750
# Grid size 5x5: IoU = 0.6400
# Grid size 6x6: IoU = 0.6111
# Grid size 7x7: IoU = 0.5510
# Grid size 8x8: IoU = 0.4062
# Grid size 9x9: IoU = 0.2963
# Grid size 10x10: IoU = 0.2200
#
# Best grid size: 4x4 with IoU = 0.8750
# ✓ Best: 4x4 (IoU: 0.8750)
# Processing image 36/50... Grid size 4x4: IoU = 0.7867
# Grid size 5x5: IoU = 0.7833
# Grid size 6x6: IoU = 0.6897
# Grid size 7x7: IoU = 0.6631
# Grid size 8x8: IoU = 0.5414
# Grid size 9x9: IoU = 0.4513
# Grid size 10x10: IoU = 0.3360
#
# Best grid size: 4x4 with IoU = 0.7867
# ✓ Best: 4x4 (IoU: 0.7867)
# Processing image 37/50... Grid size 4x4: IoU = 0.6907
# Grid size 5x5: IoU = 0.5919
# Grid size 6x6: IoU = 0.5842
# Grid size 7x7: IoU = 0.5065
# Grid size 8x8: IoU = 0.3509
# Grid size 9x9: IoU = 0.2991
# Grid size 10x10: IoU = 0.2338
#
# Best grid size: 4x4 with IoU = 0.6907
# ✓ Best: 4x4 (IoU: 0.6907)
# Processing image 38/50... Warning: ../../CROPS/image_55/image_55_grid_4_0.png or ../../CROPS/image_55/image_55_grid_4_0_mask.png not found.
# Warning: ../../CROPS/image_55/image_55_grid_5_0.png or ../../CROPS/image_55/image_55_grid_5_0_mask.png not found.
# Warning: ../../CROPS/image_55/image_55_grid_6_0.png or ../../CROPS/image_55/image_55_grid_6_0_mask.png not found.
# Warning: ../../CROPS/image_55/image_55_grid_7_0.png or ../../CROPS/image_55/image_55_grid_7_0_mask.png not found.
# Warning: ../../CROPS/image_55/image_55_grid_8_0.png or ../../CROPS/image_55/image_55_grid_8_0_mask.png not found.
# Warning: ../../CROPS/image_55/image_55_grid_9_0.png or ../../CROPS/image_55/image_55_grid_9_0_mask.png not found.
# Warning: ../../CROPS/image_55/image_55_grid_10_0.png or ../../CROPS/image_55/image_55_grid_10_0_mask.png not found.
# No valid IoU scores calculated.
# ✗ Failed
# Processing image 39/50... Grid size 4x4: IoU = 0.4375
# Grid size 5x5: IoU = 0.3600
# Grid size 6x6: IoU = 0.2222
# Grid size 7x7: IoU = 0.3265
# Grid size 8x8: IoU = 0.2812
# Grid size 9x9: IoU = 0.3333
# Grid size 10x10: IoU = 0.2800
#
# Best grid size: 4x4 with IoU = 0.4375
# ✓ Best: 4x4 (IoU: 0.4375)
# Processing image 40/50... Grid size 4x4: IoU = 0.7290
# Grid size 5x5: IoU = 0.5157
# Grid size 6x6: IoU = 0.5700
# Grid size 7x7: IoU = 0.3851
# Grid size 8x8: IoU = 0.3701
# Grid size 9x9: IoU = 0.2539
# Grid size 10x10: IoU = 0.2462
#
# Best grid size: 4x4 with IoU = 0.7290
# ✓ Best: 4x4 (IoU: 0.7290)
# Processing image 41/50... Grid size 4x4: IoU = 0.6024
# Grid size 5x5: IoU = 0.6628
# Grid size 6x6: IoU = 0.6761
# Grid size 7x7: IoU = 0.5546
# Grid size 8x8: IoU = 0.3416
# Grid size 9x9: IoU = 0.1935
# Grid size 10x10: IoU = 0.1690
#
# Best grid size: 6x6 with IoU = 0.6761
# ✓ Best: 6x6 (IoU: 0.6761)
# Processing image 42/50... Grid size 4x4: IoU = 0.4486
# Grid size 5x5: IoU = 0.5213
# Grid size 6x6: IoU = 0.3905
# Grid size 7x7: IoU = 0.3736
# Grid size 8x8: IoU = 0.3902
# Grid size 9x9: IoU = 0.3166
# Grid size 10x10: IoU = 0.1830
#
# Best grid size: 5x5 with IoU = 0.5213
# ✓ Best: 5x5 (IoU: 0.5213)
# Processing image 43/50... Grid size 4x4: IoU = 0.2917
# Grid size 5x5: IoU = 0.3580
# Grid size 6x6: IoU = 0.2436
# Grid size 7x7: IoU = 0.1288
# Grid size 8x8: IoU = 0.1651
# Grid size 9x9: IoU = 0.1685
# Grid size 10x10: IoU = 0.1213
#
# Best grid size: 5x5 with IoU = 0.3580
# ✓ Best: 5x5 (IoU: 0.3580)
# Processing image 44/50... Grid size 4x4: IoU = 0.8491
# Grid size 5x5: IoU = 0.6763
# Grid size 6x6: IoU = 0.5304
# Grid size 7x7: IoU = 0.4967
# Grid size 8x8: IoU = 0.3064
# Grid size 9x9: IoU = 0.1872
# Grid size 10x10: IoU = 0.1373
#
# Best grid size: 4x4 with IoU = 0.8491
# ✓ Best: 4x4 (IoU: 0.8491)
# Processing image 45/50... Grid size 4x4: IoU = 0.0534
# Grid size 5x5: IoU = 0.1212
# Grid size 6x6: IoU = 0.1338
# Grid size 7x7: IoU = 0.1203
# Grid size 8x8: IoU = 0.1272
# Grid size 9x9: IoU = 0.1059
# Grid size 10x10: IoU = 0.1308
#
# Best grid size: 6x6 with IoU = 0.1338
# ✓ Best: 6x6 (IoU: 0.1338)
# Processing image 46/50... Grid size 4x4: IoU = 0.6875
# Grid size 5x5: IoU = 0.6400
# Grid size 6x6: IoU = 0.6667
# Grid size 7x7: IoU = 0.5510
# Grid size 8x8: IoU = 0.3906
# Grid size 9x9: IoU = 0.2963
# Grid size 10x10: IoU = 0.2600
#
# Best grid size: 4x4 with IoU = 0.6875
# ✓ Best: 4x4 (IoU: 0.6875)
# Processing image 47/50... Grid size 4x4: IoU = 0.5302
# Grid size 5x5: IoU = 0.3913
# Grid size 6x6: IoU = 0.3337
# Grid size 7x7: IoU = 0.2136
# Grid size 8x8: IoU = 0.1283
# Grid size 9x9: IoU = 0.0785
# Grid size 10x10: IoU = 0.0724
#
# Best grid size: 4x4 with IoU = 0.5302
# ✓ Best: 4x4 (IoU: 0.5302)
# Processing image 48/50... Grid size 4x4: IoU = 0.4734
# Grid size 5x5: IoU = 0.3264
# Grid size 6x6: IoU = 0.2326
# Grid size 7x7: IoU = 0.1617
# Grid size 8x8: IoU = 0.2506
# Grid size 9x9: IoU = 0.1119
# Grid size 10x10: IoU = 0.1330
#
# Best grid size: 4x4 with IoU = 0.4734
# ✓ Best: 4x4 (IoU: 0.4734)
# Processing image 49/50... Grid size 4x4: IoU = 0.3773
# Grid size 5x5: IoU = 0.3019
# Grid size 6x6: IoU = 0.4013
# Grid size 7x7: IoU = 0.3750
# Grid size 8x8: IoU = 0.2646
# Grid size 9x9: IoU = 0.2658
# Grid size 10x10: IoU = 0.1542
#
# Best grid size: 6x6 with IoU = 0.4013
# ✓ Best: 6x6 (IoU: 0.4013)
# Processing image 50/50... Grid size 4x4: IoU = 0.4216
# Grid size 5x5: IoU = 0.2577
# Grid size 6x6: IoU = 0.3614
# Grid size 7x7: IoU = 0.2663
# Grid size 8x8: IoU = 0.1905
# Grid size 9x9: IoU = 0.1349
# Grid size 10x10: IoU = 0.1141
#
# Best grid size: 4x4 with IoU = 0.4216
# ✓ Best: 4x4 (IoU: 0.4216)

# %%
def results_to_detailed_dataframe(results, index_range):
    """
    Create a more detailed DataFrame including all IoU scores by grid size.

    Args:
        results: Dictionary from analyze_iou_across_images function
        index_range: Original index range used in the analysis

    Returns:
        df: pandas DataFrame with detailed results
    """

    # Create list to store all records
    records = []

    # Get successful image indices (excluding failed ones)
    successful_indices = [idx for idx in index_range if idx not in results['failed_images']]

    # Method 2: Create DataFrame with multiple rows per image (one for each grid size)
    for i, image_idx in enumerate(successful_indices):
        best_iou = results['best_iou_scores'][i]
        best_grid = results['best_grid_sizes'][i]

        # Add rows for all grid sizes tested for this image
        for grid_size, iou_scores_list in results['all_iou_scores'].items():
            if i < len(iou_scores_list):  # Make sure this image has data for this grid size
                records.append({
                    'image_idx': image_idx,
                    'grid_size': grid_size,
                    'iou_score': iou_scores_list[i],
                    'is_best': grid_size == best_grid,
                    'best_iou_for_image': best_iou,
                    'best_grid_for_image': best_grid
                })

    df_detailed = pd.DataFrame(records)
    return df_detailed

# %%
df = results_to_detailed_dataframe(results, index_range)
df
# Out:
#      image_idx  grid_size  iou_score  is_best  best_iou_for_image  \
# 0          628          4   0.480516    False            0.520408
# 1          628          5   0.520408     True            0.520408
# 2          628          6   0.393280    False            0.520408
# 3          628          7   0.433185    False            0.520408
# 4          628          8   0.317663    False            0.520408
# ..         ...        ...        ...      ...                 ...
# 338        368          6   0.361402    False            0.421575
# 339        368          7   0.266259    False            0.421575
# 340        368          8   0.190485    False            0.421575
# 341        368          9   0.134872    False            0.421575
# 342        368         10   0.114123    False            0.421575
#
#      best_grid_for_image
# 0                      5
# 1                      5
# 2                      5
# 3                      5
# 4                      5
# ..                   ...
# 338                    4
# 339                    4
# 340                    4
# 341                    4
# 342                    4
#
# [343 rows x 6 columns]

# %%
def results_to_summary_dataframe(results):
    """
    Create a summary DataFrame with statistics by grid size.

    Args:
        results: Dictionary from analyze_iou_across_images function

    Returns:
        df: pandas DataFrame with summary statistics
    """

    # Method 3: Summary statistics by grid size
    summary_records = []

    for grid_size, iou_scores in results['all_iou_scores'].items():
        summary_records.append({
            'grid_size': grid_size,
            'mean_iou': pd.Series(iou_scores).mean(),
            'std_iou': pd.Series(iou_scores).std(),
            'min_iou': pd.Series(iou_scores).min(),
            'max_iou': pd.Series(iou_scores).max(),
            'median_iou': pd.Series(iou_scores).median(),
        })

    df_summary = pd.DataFrame(summary_records)
    return df_summary

# %%
stats = results_to_summary_dataframe(results)
stats
# Out:
#    grid_size  mean_iou   std_iou   min_iou   max_iou  median_iou
# 0          4  0.536023  0.185937  0.053407  0.875000    0.517716
# 1          5  0.502603  0.156921  0.121236  0.800000    0.483291
# 2          6  0.453951  0.140585  0.133816  0.694444    0.444444
# 3          7  0.399047  0.127084  0.120314  0.663053    0.406431
# 4          8  0.325043  0.106209  0.127161  0.541408    0.321539
# 5          9  0.263580  0.099018  0.068974  0.469136    0.280332
# 6         10  0.202077  0.077828  0.066346  0.390000    0.194042

# %%
df_sorted = stats.sort_values('grid_size')
grid_sizes = df_sorted['grid_size'].tolist()
mean_ious = df_sorted['mean_iou'].tolist()

plt.plot(grid_sizes, mean_ious, 'bo-', linewidth=2, markersize=8)
plt.xlabel('Grid Size')
plt.ylabel('Mean IoU Score')
plt.title('Mean IoU Score vs Grid Size for 50 sampled images')
plt.grid(True, alpha=0.3)
plt.xticks(grid_sizes)

# Highlight best grid size
best_idx = df_sorted['mean_iou'].idxmax()
best_grid_size = df_sorted.loc[best_idx, 'grid_size']
best_mean_iou = df_sorted.loc[best_idx, 'mean_iou']

plt.plot(best_grid_size, best_mean_iou, 'ro', markersize=12,
         label=f'Best: {best_grid_size}x{best_grid_size}')
plt.legend()
plt.show()
